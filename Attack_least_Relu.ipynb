# %%
# ind_n1=[277, 279, 285, 287, 289, 295, 297, 299, 300, 302, 304, 310, 312, 314, 320, 322, 324, 325, 327, 329, 335, 337, 339, 345, 347, 349, 350, 352, 354, 360, 362, 364, 370, 372, 374, 375, 376, 377, 378, 379, 380, 382, 384, 385, 386, 387, 388, 389, 390, 392, 394, 395, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 407, 409, 410, 411, 412, 413, 414, 415, 417, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429, 430, 432, 434, 435, 436, 437, 438, 439, 440, 442, 444, 445, 446, 447, 448, 449, 450, 451, 452, 453, 454, 455, 457, 459, 460, 461, 462, 463, 464, 465, 467, 469, 470, 471, 472, 473, 474, 475, 476, 477, 478, 479, 480, 482, 484, 485, 486, 487, 488, 489, 490, 492, 494, 495, 496, 497, 498, 499, 500, 501, 502, 503, 504, 505]
# ind_n2=[]
ind_nn=[177, 179, 185, 187, 189, 195, 197, 199, 200, 202, 204, 210, 212, 214, 220, 222, 224, 225, 227, 229, 235, 237, 239, 245, 247, 249, 250, 252, 254, 260, 262, 264, 267, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 282, 284, 285, 286, 287, 288, 289, 290, 292, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 307, 309, 310, 311, 312, 313, 314, 315, 317, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 332, 334, 335, 336, 337, 338, 339, 340, 342, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 357, 359, 360, 361, 362, 363, 364, 365, 367, 369, 370, 371, 372, 373, 374, 375, 376, 377, 378, 379, 380, 382, 384, 385, 386, 387, 388, 389, 390, 392, 394, 395, 396, 397, 398, 399]
ind_nn2=[712, 714, 720, 722, 724, 725, 727, 729, 735, 737, 739, 745, 747, 749, 750, 752, 754, 760, 762, 764, 770, 772, 774, 775, 777, 779, 785, 787, 789, 795, 797, 799, 800, 802, 804, 810, 812, 814, 820, 822, 824, 825, 827, 829, 835, 837, 839, 845, 847, 849, 850, 852, 854, 860, 862, 864, 870, 872, 874, 875, 877, 879, 885, 887, 889, 895, 897, 899, 900, 902, 904, 910, 912, 914, 920, 922, 924, 925, 927, 929, 935, 937, 939, 945, 947, 949, 950, 952, 954, 960, 962, 964, 970, 972, 974, 975, 977, 979, 985, 987, 989, 995, 997, 999, 1000, 1002, 1004, 1010, 1012, 1014, 1020, 1022, 1024, 1025, 1027, 1029, 1035, 1037, 1039, 1045, 1047, 1049, 1050, 1052, 1054, 1060, 1062, 1064, 1067, 1069, 1070, 1071, 1072, 1073, 1074, 1075, 1076, 1077, 1078, 1079, 1080, 1082, 1084, 1085, 1086, 1087, 1088, 1089, 1090, 1092, 1094, 1095, 1096, 1097, 1098, 1099, 1100, 1101, 1102, 1103, 1104, 1105, 1107, 1109, 1110, 1111, 1112, 1113, 1114, 1115, 1117, 1119, 1120, 1121, 1122, 1123, 1124, 1125, 1126, 1127, 1128, 1129, 1130, 1132, 1134, 1135, 1136, 1137, 1138, 1139, 1140, 1142, 1144, 1145, 1146, 1147, 1148, 1149, 1150, 1151, 1152, 1153, 1154, 1155, 1157, 1159, 1160, 1161, 1162, 1163, 1164, 1165, 1167, 1169, 1170, 1171, 1172, 1173, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1182, 1184, 1185, 1186, 1187, 1188, 1189, 1190, 1192, 1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204, 1205, 1207, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1217, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1232, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1242, 1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1257, 1259, 1260, 1261, 1262, 1263, 1264, 1265, 1267, 1269, 1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1282, 1284, 1285, 1286, 1287, 1288, 1289, 1290, 1292, 1294, 1295, 1296, 1297, 1298, 1299, 1300, 1301, 1302, 1303, 1304, 1305, 1307, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1317, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1329, 1330, 1332, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1342, 1344, 1345, 1346, 1347, 1348, 1349, 1350, 1351, 1352, 1353, 1354, 1355, 1357, 1359, 1360, 1361, 1362, 1363, 1364, 1365, 1367, 1369, 1370, 1371, 1372, 1373, 1374, 1375, 1376, 1377, 1378, 1379, 1380, 1382, 1384, 1385, 1386, 1387, 1388, 1389, 1390, 1392, 1394, 1395, 1396, 1397, 1398, 1399, 1400, 1401, 1402, 1403, 1404, 1405, 1407, 1409, 1410, 1411, 1412, 1413, 1414, 1415, 1417, 1419, 1420, 1421, 1422, 1423, 1424, 1425, 1426, 1427, 1428, 1429, 1430, 1432, 1434, 1435, 1436, 1437, 1438, 1439, 1440, 1442, 1444, 1445, 1446, 1447, 1448, 1449, 1450, 1451, 1452, 1453, 1454, 1455, 1457, 1459, 1460, 1461, 1462, 1463, 1464, 1465, 1467, 1469, 1470, 1471, 1472, 1473, 1474, 1475, 1476, 1477, 1478, 1479, 1480, 1482, 1484, 1485, 1486, 1487, 1488, 1489, 1490, 1492, 1494, 1495, 1496, 1497, 1498, 1499, 1500, 1501, 1502, 1503, 1504, 1505, 1507, 1509, 1510, 1511, 1512, 1513, 1514, 1515, 1517, 1519, 1520, 1521, 1522, 1523, 1524, 1525, 1526, 1527, 1528, 1529, 1530, 1532, 1534, 1535, 1536, 1537, 1538, 1539, 1540, 1542, 1544, 1545, 1546, 1547, 1548, 1549, 1550, 1551, 1552, 1553, 1554, 1555, 1557, 1559, 1560, 1561, 1562, 1563, 1564, 1565, 1567, 1569, 1570, 1571, 1572, 1573, 1574, 1575, 1576, 1577, 1578, 1579, 1580, 1582, 1584, 1585, 1586, 1587, 1588, 1589, 1590, 1592, 1594, 1595, 1596, 1597, 1598, 1599]

# %%
import numpy as np
from pprint import pprint

from PIL import Image
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import grad
import torchvision
from torchvision import models, datasets, transforms
import torchvision.transforms as T
torch.manual_seed(50)

print(torch.__version__, torchvision.__version__)
# Out:
# 2.2.1+cpu 0.17.1+cpu

# %%
dst = datasets.CIFAR100("~/.torch", download=True)
tp = transforms.Compose([
    transforms.Resize(32),
    transforms.CenterCrop(32),
    transforms.ToTensor()
])
tt = transforms.ToPILImage()

device = "cpu"
# if torch.cuda.is_available():
#     device = "cuda"
# print("Running on %s" % device)

def label_to_onehot(target, num_classes=100):
    target = torch.unsqueeze(target, 1)
    onehot_target = torch.zeros(target.size(0), num_classes, device=target.device)
    onehot_target.scatter_(1, target, 1)
    return onehot_target

def cross_entropy_for_onehot(pred, target):
    return torch.mean(torch.sum(- target * F.log_softmax(pred, dim=-1), 1))
# Out:
# Files already downloaded and verified

# %%
def weights_init(m):
    if hasattr(m, "weight"):
        m.weight.data.uniform_(-0.5, 0.5)
    if hasattr(m, "bias"):
        m.bias.data.uniform_(-0.5, 0.5)

class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()
        # act = nn.Sigmoid
        act = nn.LeakyReLU(negative_slope=0.2)
        act_relu=nn.ReLU
        act_sig = nn.Sigmoid
        self.body = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=5, padding=5//2, stride=2,padding_mode='zeros')
        )
        self.act1=nn.Sequential(act)
        self.conv2=nn.Sequential(nn.Conv2d(64, 22, kernel_size=5, padding=5//2, stride=2,padding_mode='zeros'))
        self.act2=nn.Sequential(act_relu())
        self.conv3=nn.Sequential(nn.Conv2d(22, 12, kernel_size=5, padding=5//2, stride=1,padding_mode='zeros'))
        self.act3=nn.Sequential(act_relu())
        self.conv4=nn.Sequential(nn.Conv2d(12, 12, kernel_size=5, padding=5//2, stride=1,padding_mode='zeros'),act_relu())

        self.fc = nn.Sequential(
            nn.Linear(768, 100)
        )

    def forward(self, x):
        out1 = self.body(x)
        out2=self.act1(out1)
        out3=self.conv2(out2)
        out4=self.act2(out3)
        out5=self.conv3(out4)
        out6=self.act3(out5)
        out7=self.conv4(out6)
        out8=out7
        out=out8
        out= out.view(out.size(0), -1)
        out8=out
        out = self.fc(out)
        return out,out1,out2,out3,out4,out5,out6,out7,out8,x
net = LeNet().to(device)
net.apply(weights_init)
criterion = cross_entropy_for_onehot

# %%
######### honest partipant #########
img_index = 28
gt_data = tp(dst[img_index][0]).to(device)
gt_data_0=gt_data
gt_data = gt_data.view(1, *gt_data.size())
gt_label = torch.Tensor([dst[img_index][1]]).long().to(device)
gt_label = gt_label.view(1, )
gt_onehot_label = label_to_onehot(gt_label, num_classes=100)

# plt.imshow(tt(gt_data[0].cpu()))
# plt.title("Ground truth image")
# print("GT label is %d." % gt_label.item(), "\nOnehot label is %d." % torch.argmax(gt_onehot_label, dim=-1).item())

# compute original gradient
out,out1,out2,out3,out4,out5,out6,out7,out8,org_x = net(gt_data)
y = criterion(out, gt_onehot_label)

dy_dx = torch.autograd.grad(y, net.parameters())



# share the gradients with other clients
original_dy_dx = [_.numpy() for _ in dy_dx]

# %%
param=[i for i in net.parameters()]
print(param[0])
# Out:
# Parameter containing:
# tensor([[[[ 4.6393e-01, -1.9019e-01,  7.4853e-02,  1.0395e-01, -3.1081e-01],
#           [ 2.4993e-01, -3.2538e-01,  3.0873e-01, -1.1793e-01, -2.8081e-01],
#           [ 3.9504e-03, -2.9363e-02,  3.1609e-01, -4.0963e-01,  2.4033e-01],
#           [-4.8491e-01,  2.7906e-01,  1.6264e-01, -3.9581e-01,  3.2725e-02],
#           [ 3.1509e-01,  4.1207e-01, -3.5580e-01,  4.6768e-01,  2.9714e-02]],
#
#          [[-1.6461e-01, -4.3595e-01, -2.9905e-01, -2.3300e-01, -3.8616e-01],
#           [ 1.9024e-01,  1.4719e-01, -2.1570e-01,  2.5926e-01, -3.8944e-01],
#           [ 3.9834e-01,  4.7343e-01, -5.0305e-03, -9.5906e-02,  4.7208e-02],
#           [-3.2910e-01,  2.7487e-01, -4.4483e-01,  3.0314e-01,  4.1173e-01],
#           [ 4.3394e-01, -2.9483e-01, -3.1113e-01,  2.1244e-01, -1.1677e-01]],
#
#          [[-1.7423e-01, -3.0256e-01, -4.6601e-01, -2.5385e-01, -1.1581e-01],
#           [ 1.6239e-01,  4.4139e-01, -3.0447e-01, -2.5829e-01,  1.6868e-01],
# ...

# %%
param = [i.detach().numpy() for i in net.parameters() if i.requires_grad]

# %%
#Compute the derivitve of the output of last conv layer ( sum ( bias * weight))
FC4_gradient=[i*0 for i in range(0,768)]
FC4_values=[i*0 for i in range(0,768)]
for i in range(0,100):
    for n in range(0,768):
      FC4_gradient[n]+= original_dy_dx[9][i]*param[8][i][n]

# %%
# Compute the values of the ouptut of last conv layer ( weigh/bias)

for n in range(0,768):
  list=[]
  for k in range(0,100):
    if original_dy_dx[9][k]!=0:
      FC4_values[n]= original_dy_dx[8][k][n]/original_dy_dx[9][k]

# %%
#verify the reslut
n=0
for i in range(0,768):
  if  FC4_values[i]!=out8[0][i]:
    print(i)
    print(FC4_values[i])
    print(out8[0][i])
    print("------------------------------")
    n+=1
print(n)
# Out:
# 0

# %%
# compute the derivatives and the values before the activation function of the last convlayer
FC4_pre_gradient=FC4_gradient.copy()
FC4_pre_values=FC4_values.copy()
for i in range(0,768):
  if FC4_values[i]<=0:
    #FC4_pre_values[i]=FC4_values[i]/0.2
    FC4_pre_gradient[i]=0

# %%
# verify the values of the derivatives before the last conv layer
k=0
for n in range(12):
    sum=0
    for i in range(64):
        sum+=FC4_pre_gradient[n*64+i]
    print(sum," ",original_dy_dx[7][n])
    if sum!=original_dy_dx[7][n]:
        k+=1
print(k)
# Verify the result of the values
out7= out7.view(out7.size(0), -1)
n=0
for i in range(0,768):
  if  FC4_pre_values[i]!=out7[0][i]:
    print(i)
    print(FC4_pre_values[i])
    print(out7[0][i])
    print("------------------------------")
    n+=1
print(n)
# Out:
# -2.906103551387787   -2.906104
# 0.7248654961585999   0.72486526
# 3.642496943473816   3.642497
# 0.5306552648544312   0.53065526
# 1.404737412929535   1.4047374
# 2.125897705554962   2.125898
# 2.5060503482818604   2.5060503
# -2.757667899131775   -2.757668
# 3.6724424958229065   3.6724422
# 3.602592885494232   3.6025932
# 0.08571434020996094   0.08571422
# 3.1390236020088196   3.1390238
# 10
# 0

# %% [markdown]
# Trying to minimize the number of equations

# %%
a=np.array(FC4_pre_gradient).reshape(12,64)
a=np.array(a)
#construct the input of the 3rd conv
a_reshape=a.reshape(12,8,8)
Filters_gradients=np.array(original_dy_dx[6]).reshape(12,12,5,5)
x=[]
for n in range(12):
    cord_a=[]
    cord_b=[]
    rank=0
    for i in range(12):
        for k in range(5):
            for l in range(5):
                if(rank==64):
                    break
                cord_b.append(Filters_gradients[i][n][k][l])
                array_gradients=np.zeros(144).reshape(12,12)
                array_gradients[k:k+8,l:l+8]=a_reshape[i:i+1]
                cord_a.append(array_gradients[2:10,2:10].reshape(64))
                current_rank=np.linalg.matrix_rank(cord_a)
                if (current_rank==rank):
                    cord_a=cord_a[:-1]
                    cord_b=cord_b[:-1]
                rank=current_rank
    sol=np.linalg.solve(cord_a,cord_b)
    sol2=sol.reshape(8,8)
    x.append(sol2)

# %%
x=np.array(x)
x=x.reshape(12*64)

# %%
#verify the values of the output of third convloution
k=0
out6= out6.view(out6.size(0), -1)
out6=out6.reshape(12*64)
for i in range(12*64):
    if int(out6[i])!=int(x[i]):
        print(out6[i]," ",x[i])
        k+=1
print(k)
FC3_values=np.array(x).copy()
FC3_pre_values=np.array(x).copy()
# Out:
# 0

# %%
FC3_values=np.array(x).copy()
FC3_pre_values=np.array(x).copy()
FC3_gradients=np.array([i*0.0 for i in range(12*12*12)])
Output_gradients=np.array(FC4_pre_gradient).reshape(12,8,8)
FC3_gradients=FC3_gradients.reshape(12,12,12)
Filters=np.array(param[6]).reshape(12,12,5,5)
for n in range(12):
    for i in range(12):
        for d in range(8):
            for t in range(8):
                for k in range(5):
                    for l in range(5):
                        FC3_gradients[n][d+k][t+l]+=Filters[i][n][k][l]*Output_gradients[i][d][t]
FC3_pre_gradient=FC3_gradients[:,2:10,2:10].reshape(768)
FC3_pre_gradient=FC3_pre_gradient
for i in range(0,768):
  if out6[i]<=0:
    # FC3_pre_values[i]=FC3_values[i]/0.2
    FC3_pre_gradient[i]=0
    
#verify the gradients of conv3
k=0
for n in range(12):
    sum=0
    for i in range(64):
        sum+=FC3_pre_gradient[n*64+i]
    if int(sum)!=int(original_dy_dx[5][n]):
        print(sum,original_dy_dx[5][n])
        k+=1
print(k)
# #verify the values before the activation layer of the third convloution layer
# k=0
# out5= out5.view(out5.size(0), -1)
# out5=torch.tensor(out5).reshape(12*64)
# for i in range(12*64):
#     if int(out5[i])!=int(FC3_pre_values[i]):
#         k+=1
# print(k)
# Out:
# 0

# %%
# FC3_gradients=np.array([i*0.0 for i in range(12*12*3)])
# Output_gradients=np.array(FC4_pre_gradient).reshape(3,8,8)
# FC3_gradients=FC3_gradients.reshape(3,12,12)

# %%
# Filters=np.array(param[6]).reshape(64,64,5,5)

# %%
# for n in range(64):
#     for i in range(64):
#         for d in range(8):
#             for t in range(8):
#                 for k in range(5):
#                     for l in range(5):
#                         FC3_gradients[n][d+k][t+l]+=Filters[i][n][k][l]*Output_gradients[i][d][t]

# %%
# # compute the derivatives and the values before the activation function of the second convlayer

# FC3_pre_gradient=FC3_gradients[:,2:10,2:10].reshape(768)
# FC3_pre_gradient=FC3_pre_gradient
# for i in range(0,768):
#   if FC3_values[i]<0:
#     FC3_pre_values[i]=FC3_values[i]/0.2
#     FC3_pre_gradient[i]=FC3_pre_gradient[i]*0.2

# %%
#verify the gradients of conv3
k=0
for n in range(12):
    sum=0
    for i in range(64):
        sum+=FC3_pre_gradient[n*64+i]
    if int(sum)!=int(original_dy_dx[5][n]):
        k+=1
print(k)
# Out:
# 0

# %%
#verify the values before the activation layer of the third convloution layer
k=0
out5= out5.view(out5.size(0), -1)
out5=torch.tensor(out5).reshape(12*64)
for i in range(12*64):
    if int(out5[i])!=int(FC3_pre_values[i]):
        k+=1
print(k)
# Out:
# 365
# C:\Users\ta18336\AppData\Local\Temp\ipykernel_13848\2603803659.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   out5=torch.tensor(out5).reshape(12*64)

# %%
a=np.array(FC3_pre_gradient).reshape(12,8,8)
a_reshape=a.reshape(12,8,8)
Filters_gradients=np.array(original_dy_dx[4]).reshape(12,22,5,5)
x=[]
for n in range(22):
    cord_a=[]
    cord_b=[]
    rank=0
    for i in range(12):
        for k in range(5):
            for l in range(5):
                if(rank==64):
                    break
                cord_b.append(Filters_gradients[i][n][k][l])
                array_gradients=np.zeros(144).reshape(12,12)
                array_gradients[k:k+8,l:l+8]=a_reshape[i:i+1]
                cord_a.append(array_gradients[2:10,2:10].reshape(64))
                current_rank=np.linalg.matrix_rank(cord_a)
                if (current_rank==rank):
                    cord_a=cord_a[:-1]
                    cord_b=cord_b[:-1]
                rank=current_rank
    sol=np.linalg.solve(cord_a,cord_b)
    sol2=sol.reshape(8,8)
    x.append(sol2)
    # x.append(sol2[2:10,2:10])
# print(x[0])

#verify the values of the output of third convloution
k=0
out4= out4.view(out4.size(0), -1)
out4=out4.reshape(22*64)
x=np.array(x).reshape(22*64)
print(x.shape)
for i in range(22*64):
    if int(out4[i])!=int(x[i]):
        k+=1
print(k)
# FC3_values=np.array(x).copy()
# FC3_pre_values=np.array(x).copy()
# Out:
# (1408,)
# 0

# %%
print(len(cord_b))
print(len(cord_a))
# Out:
# 64
# 64

# %%
print(out4[0],x[0])
# Out:
# tensor(0., grad_fn=<SelectBackward0>) -6.232151139396693e-06

# %%
FC2_values=np.array(x).copy()
FC2_pre_values=np.array(x).copy()
FC2_gradients=np.array([i*0.0 for i in range(12*12*22)])
Output_gradients_2=np.array(FC3_pre_gradient).reshape(12,8,8)
FC2_gradients=FC2_gradients.reshape(22,12,12)
Filters=np.array(param[4]).reshape(12,22,5,5)

# %%
for n in range(22):
    for i in range(12):
        for d in range(8):
            for t in range(8):
                for k in range(5):
                    for l in range(5):
                        FC2_gradients[n][d+k][t+l]+=Filters[i][n][k][l]*Output_gradients_2[i][d][t]

# %%
FC2_pre_gradient=FC2_gradients[:,2:10,2:10].reshape(64*22)
FC2_values=FC2_values.reshape(64*22)
FC2_pre_values=FC2_values.reshape(64*22)
for i in range(0,64*22):
  if out4[i]<=0:
     FC2_pre_gradient[i]=0
  else:
     print(FC2_values[i]," ",out4[i])
#verify the gradients of conv3
# k=0
# for n in range(16):
#     sum=0
#     for i in range(64):
#         sum+=FC2_pre_gradient[n*64+i]
#     if int(sum)==int(original_dy_dx[3][n]):
#         print(sum,original_dy_dx[3][n] )
#         k+=1
# print(k)
# #verify the values before the activation layer of the third convloution layer
# k=0
# out3= out3.view(out3.size(0), -1)
# out3=torch.tensor(out3).reshape(16*64)
# for i in range(16*64):
#     if int(out3[i])!=int(FC2_pre_values[i]):
#         print(out3[i]," ",FC2_pre_values[i])
#         k+=1
# print(k)
# Out:
# 0.454744960246457   tensor(0.4547, grad_fn=<SelectBackward0>)
# 4.712727289487341   tensor(4.7127, grad_fn=<SelectBackward0>)
# 2.2964948528308735   tensor(2.2965, grad_fn=<SelectBackward0>)
# 3.550420128803177   tensor(3.5504, grad_fn=<SelectBackward0>)
# 0.8247864912352003   tensor(0.8248, grad_fn=<SelectBackward0>)
# 0.4028146871323526   tensor(0.4028, grad_fn=<SelectBackward0>)
# 1.1231169489143973   tensor(1.1231, grad_fn=<SelectBackward0>)
# 3.826764436465334   tensor(3.8268, grad_fn=<SelectBackward0>)
# 0.37522594535985215   tensor(0.3752, grad_fn=<SelectBackward0>)
# 6.03000817189449   tensor(6.0300, grad_fn=<SelectBackward0>)
# 2.1778754171646986   tensor(2.1779, grad_fn=<SelectBackward0>)
# 3.444735391781366   tensor(3.4447, grad_fn=<SelectBackward0>)
# 3.2200233104025586   tensor(3.2200, grad_fn=<SelectBackward0>)
# 0.8404426877628799   tensor(0.8404, grad_fn=<SelectBackward0>)
# 1.409306332565302   tensor(1.4093, grad_fn=<SelectBackward0>)
# ...

# %%
indices=[]
#construct the values of the input of the second layer
a_reshape=FC2_pre_gradient.reshape(22,8,8)
print(original_dy_dx[2].shape)
Filters_gradients=np.array(original_dy_dx[2]).reshape(22,64,5,5)
x=[]
for n in range(1):
    cord_a=[]
    cord_b=[]
    rank=0
    for i in range(22):
        for k in range(5):
            for l in range(5):
                if(rank==256):
                   break
                cord_b.append(Filters_gradients[i][n][k][l])
                array_gradients=np.zeros(400).reshape(20,20)
                array_gradients[k:k+16:2,l:l+16:2]=a_reshape[i:i+1]
                cord_a.append(array_gradients[2:18,2:18].reshape(256))
                current_rank=np.linalg.matrix_rank(cord_a)
                if (current_rank==rank):
                    indices.append(i*25+k*5+l)
                    cord_a=cord_a[:-1]
                    cord_b=cord_b[:-1]
                rank=current_rank
# Out:
# (22, 64, 5, 5)

# %%
#construct the values of the input of the second layer
a_reshape=FC2_pre_gradient.reshape(22,8,8)
print(original_dy_dx[2].shape)
Filters_gradients=np.array(original_dy_dx[2]).reshape(22,64,5,5)
x=[]
for n in range(64):
    cord_a=[]
    cord_b=[]
    rank=0
    for i in range(22):
        for k in range(5):
            for l in range(5):
                if(rank==256):
                   break
                cord_b.append(Filters_gradients[i][n][k][l])
                array_gradients=np.zeros(400).reshape(20,20)
                array_gradients[k:k+16:2,l:l+16:2]=a_reshape[i:i+1]
                cord_a.append(array_gradients[2:18,2:18].reshape(256))
    cord_a=np.delete(cord_a,indices,axis=0)
    cord_b=np.delete(cord_b,indices,axis=0)
    cord_a=cord_a[0:256]
    cord_b=cord_b[0:256]
    sol=np.linalg.solve(cord_a,cord_b)
    sol2=sol.reshape(16,16)
    x.append(sol2)
# Out:
# (22, 64, 5, 5)

# %%
print(len(cord_a))
print(np.linalg.matrix_rank(cord_a))
# Out:
# 256
# 256

# %%
# def find_dependent_rows(matrix):
#     full_rank = np.linalg.matrix_rank(matrix)
#     dependent_rows = []

#     # Check each row by temporarily removing it and checking the rank
#     for i in range(matrix.shape[0]):
#         # Create a new matrix without the i-th row
#         temp_matrix_4 = np.delete(matrix, i, axis=0)
#         if np.linalg.matrix_rank(temp_matrix_4) == full_rank:
#             dependent_rows.append(i+1)  # Store the original index of the dependent row

#     return dependent_rows


# dependent_indices = find_dependent_rows(np.array(cord_a))
# print("Dependent row indices:", dependent_indices)
# print("Dependent rows:")

# %%
# file1=open(r'C:\Users\ta18336\Desktop\matrix2.out','w')
# for i in range(361):
#     str1=""
#     for j in range(277,278):
#         str1+=f"{cord_a[j][i]:>5.1f}|"
#     # file1.write(f"{cord_a[0][i]:.1f}|{cord_a[2][i]:.1f}|{cord_a[4][i]:.1f}|{cord_a[10][i]:.1f}|{cord_a[12][i]:.1f}|{cord_a[14][i]:.1f}|{cord_a[20][i]:.1f}|{cord_a[22][i]:.1f}|{cord_a[24][i]:.1f}|{cord_a[277][i]:.1f} \n")
#     file1.write(str1+"\n")
# file1.close()

# %%
out2= out2.view(out2.size(0), -1)
z=np.array(x).reshape(16384)

# %%
FC1_values=np.array(z).copy()
FC1_pre_values=np.array(z).copy()
FC1_gradients=np.array([i*0.0 for i in range(22*22*64)])
Output_gradients_1=np.array(FC2_pre_gradient).reshape(22,8,8)
FC1_gradients=FC1_gradients.reshape(64,22,22)
Filters=np.array(param[2]).reshape(22,64,5,5)

# %%
#construct the input gardient of the second layer
for n in range(64):
    for i in range(22):
        for d in range(0,16,2):
            for t in range(0,16,2):
                for k in range(5):
                    for l in range(5):
                        FC1_gradients[n][d+k][t+l]+=Filters[i][n][k][l]*Output_gradients_1[i][int(d/2)][int(t/2)]

# %%
FC1_pre_gradient=FC1_gradients[:,2:18,2:18].reshape(16384)


for i in range(0,16384):
  if FC1_values[i]<0:
    FC1_pre_values[i]=FC1_values[i]/0.2
    FC1_pre_gradient[i]=FC1_pre_gradient[i]*0.2
k=0
for n in range(64):
    sum=0
    for i in range(256):
        sum+=FC1_pre_gradient[n*256+i]
    print(sum, " ", original_dy_dx[1][n])
    if int(sum)!=int(original_dy_dx[1][n]):
        k+=1
print(k)
#verify the values before the activation layer of the third convloution layer
# Out:
# 29.831867695557925   29.831873
# 73.30301838103611   73.30302
# -4.020305007153626   -4.020286
# -94.69833335100843   -94.69836
# -7.890062501994034   -7.890052
# -200.4749600005906   -200.47504
# -41.43470268687946   -41.434692
# 530.3110195674395   530.3112
# 128.46086621100233   128.46094
# -17.683448990179958   -17.683456
# 52.16852908922551   52.1685
# -17.737175631419138   -17.73724
# -38.75945409845393   -38.759415
# -44.48483586842975   -44.484848
# -444.26294587747356   -444.26282
# -259.0176054191788   -259.01755
# -174.5933245580852   -174.59334
# -514.8980579680137   -514.89825
# 116.19033180585735   116.19041
# 121.90243013818197   121.9025
# 25.24107817605498   25.241074
# -54.23503607426878   -54.235043
# -30.36518784810153   -30.365238
# -2.0102606428582   -2.0102577
# -122.10287009162835   -122.10278
# -23.041451641745567   -23.041458
# 38.64018275880523   38.640175
# -15.426267852828747   -15.426296
# 34.39320181625441   34.393265
# 148.68068963873114   148.68063
# ...

# %%
print(original_dy_dx[0].shape)
# Out:
# (64, 3, 5, 5)

# %%
#construct the input of the first layer
a_reshape=FC1_pre_gradient.reshape(64,16,16)
Filters_gradients=np.array(original_dy_dx[0]).reshape(64,3,5,5)
x=[]
for n in range(3):
    cord_a=[]
    cord_b=[]
    rank=0
    for i in range(64):
        for k in range(5):
            for l in range(5):
                cord_b.append(Filters_gradients[i][n][k][l])
                array_gradients=np.zeros(1296).reshape(36,36)
                array_gradients[k:k+32:2,l:l+32:2]=a_reshape[i:i+1]
                cord_a.append(array_gradients[2:34,2:34].reshape(1024))
    cord_a= np.delete(cord_a,ind_nn2, axis=0)
    cord_b= np.delete(cord_b,ind_nn2, axis=0)
    sol=np.linalg.solve(cord_a,cord_b)
    x.append(sol)

# %%
#verify that constructed data
k=0
out1= out1.view(out1.size(0), -1)
out1=torch.tensor(out1).reshape(64*16*16)
for i in range(64*16*16):
    if int(out1[i])!=int(FC1_pre_values[i]):
        k+=1
    print(out1[i]," ",FC1_pre_values[i])
print(k)
# Out:
# C:\Users\ta18336\AppData\Local\Temp\ipykernel_13848\476150838.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   out1=torch.tensor(out1).reshape(64*16*16)
# tensor(0.8019)   0.8019074733394288
# tensor(1.3261)   1.3260801027322646
# tensor(1.1043)   1.1042748554980442
# tensor(1.3707)   1.3706707652426344
# tensor(1.2915)   1.2914618558855497
# tensor(1.2957)   1.2957500058527733
# tensor(1.3611)   1.3610663335443727
# tensor(1.3191)   1.3190823876160007
# tensor(1.3219)   1.3219468617304262
# tensor(1.3195)   1.3194896745319682
# tensor(1.3195)   1.3194908393394957
# tensor(1.3195)   1.3194896475924829
# tensor(1.3195)   1.3194951112157318
# tensor(1.3195)   1.3194882005726487
# tensor(1.3195)   1.3194805341281695
# tensor(0.6893)   0.6892801341217616
# tensor(-1.8986)   -1.89865103963837
# tensor(-1.3883)   -1.3882919951529122
# ...

# %%
reconstructed_val=torch.tensor(x).reshape(3,32,32)
oringinal_val=torch.tensor(org_x).reshape(3,32,32)
plt.subplot(1, 2,  1)
plt.imshow(tt(oringinal_val))
plt.axis('off')
plt.subplot(1, 2,  2)
plt.imshow(tt(reconstructed_val))
plt.title("reconstructed")
plt.axis('off')
# Out:
# C:\Users\ta18336\AppData\Local\Temp\ipykernel_13848\1935550011.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   oringinal_val=torch.tensor(org_x).reshape(3,32,32)
# (-0.5, 31.5, 31.5, -0.5)

# %%
#measure the quality of the image

from skimage.metrics import mean_squared_error, structural_similarity
from skimage.io import imread
from skimage.color import rgb2gray

mse=mean_squared_error(np.array(oringinal_val),np.array(reconstructed_val))
print(f'The Error in the construction error: {mse}')

Max=255
PSNR = 20*np.log10(max)-10*np.log10(mse)
print(PSNR)
# Out:
# The Error in the construction error: 6.320166670104301e-08
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'builtin_function_or_method' object has no attribute 'log10'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 11
#       8 print(f'The Error in the construction error: {mse}')
#      10 Max=255
# ---> 11 PSNR = 20*np.log10(max)-10*np.log10(mse)
#      12 print(PSNR)
#
# TypeError: loop of ufunc does not support argument 0 of type builtin_function_or_method which has no callable log10 method

# %%
mse=mean_squared_error(np.array(oringinal_val),np.array(reconstructed_val))

# %%
# from skimage.color import rgb2gray
# import skimage.io as io
# our_1 = io.imread('Our_approach\cifar_4.png')
# plt.subplot(2, 4,  1)
# plt.imshow(our_1)
# plt.axis('off')
# our_1 = io.imread('Our_approach\cifar_5.png')
# plt.subplot(2, 4,  2)
# plt.imshow(our_1)
# plt.axis('off')
# our_1 = io.imread('Our_approach\cifar_6.png')
# plt.subplot(2, 4,  3)
# plt.imshow(our_1)
# plt.axis('off')
# our_1 = io.imread('Our_approach\cifar_11.png')
# plt.subplot(2, 4,  4)
# plt.imshow(our_1)
# plt.axis('off')


# R_1 = io.imread('R-GAP\cifar_4.png')
# plt.subplot(2, 4,  5)
# plt.imshow(R_1)
# plt.axis('off')
# R_1 = io.imread('R-GAP\Cifar_5.png')
# plt.subplot(2, 4,  6)
# plt.imshow(R_1)
# plt.axis('off')
# R_1 = io.imread('R-GAP\cifar_6.png')
# plt.subplot(2, 4,  7)
# plt.imshow(R_1)
# plt.axis('off')
# R_1 = io.imread('R-GAP\cifar_11.png')
# plt.subplot(2, 4,  8)
# plt.imshow(R_1)
# plt.axis('off')

# %%
image = io.imread('Our_approach\cifar_4.png')
rgap_image= io.imread('R-GAP\cifar_4.png')
dlg_image=io.imread('DLG\DLg_cifar_4.png')
original=io.imread('original_4.png')
mse1=mean_squared_error(np.array(image),np.array(original))
mse2=mean_squared_error(np.array(image),np.array(rgap_image))
mse3=mean_squared_error(np.array(image),np.array(dlg_image))
print("PSRN using mse: ")
print(f'Our Approach: {mse1}')
print(f'R-Gap: {mse2}')
print(f'DlG: {mse3}')
print('---------------------------------------')
image = io.imread('Our_approach\cifar_5.png')
rgap_image= io.imread('R-GAP/Cifar_5.png')
dlg_image=io.imread('DLG\DlG_cifar_5.png')
original=io.imread('original_5.png')
mse1=mean_squared_error(np.array(image),np.array(original))
mse2=mean_squared_error(np.array(image),np.array(rgap_image))
mse3=mean_squared_error(np.array(image),np.array(dlg_image))
print("PSRN using mse: ")
print(f'Our Approach: {mse1}')
print(f'R-Gap: {mse2}')
print(f'DlG: {mse3}')
print('---------------------------------------')
image = io.imread('Our_approach\cifar_6.png')
rgap_image= io.imread('R-GAP\cifar_6.png')
dlg_image=io.imread('DLG\dlg_cifar_6.png')
original=io.imread('original_6.png')
mse1=mean_squared_error(np.array(image),np.array(original))
mse2=mean_squared_error(np.array(image),np.array(rgap_image))
mse3=mean_squared_error(np.array(image),np.array(dlg_image))
print("PSRN using mse: ")
print(f'Our Approach: {mse1}')
print(f'R-Gap: {mse2}')
print(f'DlG: {mse3}')
print('---------------------------------------')
image = io.imread('Our_approach\cifar_11.png')
rgap_image= io.imread('R-GAP\cifar_11.png')
dlg_image=io.imread('DLG\DLg_cifar_11.png')
original=io.imread('original_11.png')
mse1=mean_squared_error(np.array(image),np.array(original))
mse2=mean_squared_error(np.array(image),np.array(rgap_image))
mse3=mean_squared_error(np.array(image),np.array(dlg_image))
ssim=structural_similarity(image,dlg_image,win_size=5,data_range=image.max() - image.min())
print("PSRN using mse: ")
print(f'Our Approach: {mse1}')
print(f'R-Gap: {mse2}')
print(f'DlG: {mse3}')

print(ssim)

psrn=peak
# Out:
# PSRN using mse:
# Our Approach: 0.157470703125
# R-Gap: 455.13190592447916
# DlG: 36.955938313802086
# ---------------------------------------
# PSRN using mse:
# Our Approach: 0.17248128255208334
# R-Gap: 303.1210530598958
# DlG: 7.9580086263020835
# ---------------------------------------
# PSRN using mse:
# Our Approach: 2467.6510530598957
# R-Gap: 1054.445448404948
# DlG: 1.739306640625
# ---------------------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1035], line 44
#      42 mse2=mean_squared_error(np.array(image),np.array(rgap_image))
#      43 mse3=mean_squared_error(np.array(image),np.array(dlg_image))
# ---> 44 ssim=structural_similarity(image,dlg_image,win_size=5,data_range=image.max() - image.min())
#      45 print("PSRN using mse: ")
#      46 print(f'Our Approach: {mse1}')
#
# ...

# %%
# fig, axes = plt.subplots(nrows=3, ncols=4,figsize=(16,12))
# plt.subplots_adjust(left=0, right=.5, top=.5, bottom=0, wspace=0, hspace=-0.6)
# plt.grid()
# our_1 = io.imread('Our_approach\cifar_4.png')
# axes[0,0].imshow(our_1)
# axes[0,0].axis('off')
# axes[0,0].grid('off')
# our_1 = io.imread('Our_approach\cifar_5.png')
# axes[0,1].imshow(our_1)
# axes[0,1].axis('off')
# our_1 = io.imread('Our_approach\cifar_6.png')
# axes[0,2].imshow(our_1)
# axes[0,2].axis('off')
# our_1 = io.imread('Our_approach\cifar_11.png')
# axes[0,3].imshow(our_1)
# axes[0,3].axis('off')


# R_1 = io.imread('R-GAP\cifar_4.png')
# axes[1,0].imshow(R_1)
# axes[1,0].axis('off')
# R_1 = io.imread('R-GAP\Cifar_5.png')
# axes[1,1].imshow(R_1)
# axes[1,1].axis('off')
# R_1 = io.imread('R-GAP\cifar_6.png')
# axes[1,2].imshow(R_1)
# axes[1,2].axis('off')
# R_1 = io.imread('R-GAP\cifar_11.png')
# axes[1,3].imshow(R_1)
# axes[1,3].axis('off')
# axes[1,3].grid('off')

# R_1 = io.imread('DLG\DLg_cifar_4.png')
# axes[2,0].imshow(R_1)
# axes[2,0].axis('off')
# R_1 = io.imread('DLG\DlG_cifar_5.png')
# axes[2,1].imshow(R_1)
# axes[2,1].axis('off')
# R_1 = io.imread('DLG\dlg_cifar_6.png')
# axes[2,2].imshow(R_1)
# axes[2,2].axis('off')
# R_1 = io.imread('DLG\DLg_cifar_11.png')
# axes[2,3].imshow(R_1)
# axes[2,3].axis('off')
# axes[2,3].grid('off')
